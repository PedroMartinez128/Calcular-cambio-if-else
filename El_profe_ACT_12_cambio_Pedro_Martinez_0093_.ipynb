# %% [markdown]
# ## Pedro Martinez NL = 34 Fecha 26/marzo/2026
# ### Calculando el cambio usando if else
# ### mirar diagrama de flujo
# <img src="https://raw.githubusercontent.com/PedroMartinez128/Calcular-cambio-if-else/refs/heads/main/Cambio%205.jpg" width="300" height="200" alt="Texto alternativo">
#
# ## Las variables
# 1. CP---> Costo del producto
# 2. CD---> Cantidad de dinero
# 3. Camibio
#
# ## Formulas
# $Cambio=CD - CP$
# ## Diagrama de flujo lucidChart
#
# <img src="https://raw.githubusercontent.com/PedroMartinez128/Calcular-cambio-if-else/refs/heads/main/DF%20if%20else%20Cambio%202.png" width="350" height="500" alt="Texto alternativo">

# %%
# Para cuando es  verdadero (SI)
# Calculando el cambio usando if else
# Datos de entrada CP,CD
# Mostrar cambio si es falso
# Si es verdadero mostrar No alcanza
CP=float(input("Ingrese el costo del producto: "))
CD=float(input("Ingrese la cantidad de dinero: "))
if CP > CD:
    print("No alcanza")
else:
    Cambio= CD - CP
    print("El cambio es: ",Cambio)
print("Fin del programa")
print("Programa realizado por Pedro Martinez NL = 34")
# Out:
# Ingrese el costo del producto: 500
# Ingrese la cantidad de dinero: 400
# No alcanza
# Fin del programa
# Programa realizado por Pedro Martinez NL = 34

# %%
# Para cuando es falso (NO)
# Calculando el cambio usando if else
# Datos de entrada CP,CD
# Mostrar cambio si es falso
# Si es verdadero mostrar No alcanza
CP=float(input("Ingrese el costo del producto: "))
CD=float(input("Ingrese la cantidad de dinero: "))
if CP > CD:
    print("No alcanza")
else:
    Cambio= CD - CP
    print("El cambio es: ",Cambio)
print("Fin del programa")
print("Programa realizado por Pedro Martinez NL = 34")
# Out:
# Ingrese el costo del producto: 250
# Ingrese la cantidad de dinero: 300
# El cambio es:  50.0
# Fin del programa
# Programa realizado por Pedro Martinez NL = 34

# %% [markdown]
# ## Relacion entre codigo y Diagrama de flujo
# <img src="https://raw.githubusercontent.com/PedroMartinez128/Calcular-cambio-if-else/refs/heads/main/Tldraw%20Codigo%20DF.png" width="800" height="800" alt="Texto alternativo">
